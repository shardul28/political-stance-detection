# %% [markdown]
# <a href="https://colab.research.google.com/github/shardul28/political-stance-detection/blob/Mscproject/scrapeddata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ##LEFT
# The Wire
# NDTV
# Indian Express
# The Hindu
# Amnesty India
# Bloomberg-Quint (1)
# Reuters India (2)
# BBC India (3)
# Scroll.in
# TheWeek

# ABP News
# IndiaToday / Aajtak
# Hindustan Times
# Indiatimes (6)
# DNA India (7)


##Center
# Times Of India
# ANI media agency
# PTI media agency
# WION (11)
# DD News
# Deccan Chronicle


##RIGHT
# TimesNow
# IndiaTV
# Zee News
# Republic TV / Republic Bharat

# %%
import pandas as pd
import requests

# Fox
url_fox1 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=fox-news&'
       'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_fox1 = requests.get(url_fox1)

url_fox2 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=fox-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_fox2 = requests.get(url_fox2)

url_fox3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=fox-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_fox3 = requests.get(url_fox3)


url_fox4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=fox-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_fox4 = requests.get(url_fox4)


url_fox5 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=fox-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_fox5 = requests.get(url_fox5)


url_fox6 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=fox-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_fox6 = requests.get(url_fox6)


url_fox7 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=fox-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_fox7 = requests.get(url_fox7)

# %%
# National Review
url_nreview1 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_nreview1 = requests.get(url_nreview1)

url_nreview2 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_nreview2 = requests.get(url_nreview2)

url_nreview3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_nreview3 = requests.get(url_nreview3)

url_nreview4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_nreview4 = requests.get(url_nreview4)

url_nreview5 = ('http://newsapi.org/v2/everything?'
       'q=war&'
        'sources=national-review&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_nreview5 = requests.get(url_nreview5)


url_nreview6 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_nreview6 = requests.get(url_nreview6)


url_nreview7 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_nreview7 = requests.get(url_nreview7)

# %%
# Breitbart
url_bart1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_bart1 = requests.get(url_bart1)

url_bart2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_bart2 = requests.get(url_bart2)

url_bart3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_bart3 = requests.get(url_bart3)

url_bart4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_bart4 = requests.get(url_bart4)

url_bart5 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_bart5 = requests.get(url_bart5)
url_bart6 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_bart6 = requests.get(url_bart6)
url_bart7 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_bart7 = requests.get(url_bart7)

# %% [markdown]
# ##url changes req from here

# %%
# American Conservative
url_amcon1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=the-american-conservative&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_amcon1 = requests.get(url_amcon1)

url_amcon2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=the-american-conservative&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_amcon2 = requests.get(url_amcon2)

url_amcon3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=the-american-conservative&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_amcon3 = requests.get(url_amcon3)

url_amcon4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=the-american-conservative&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_amcon4 = requests.get(url_amcon4)

url_amcon5 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=the-american-conservative&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_amcon5 = requests.get(url_amcon5)

url_amcon6 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=the-american-conservative&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_amcon6 = requests.get(url_amcon6)

url_amcon7 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=the-american-conservative&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_amcon7 = requests.get(url_amcon7)

# %%
#Washington Times
url_washt1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=the-washington-times&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_washt1 = requests.get(url_washt1)

url_washt2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=the-washington-times&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_washt2 = requests.get(url_washt2)

url_washt3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=the-washington-times&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_washt3 = requests.get(url_washt3)

url_washt4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=the-washington-times&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_washt4 = requests.get(url_washt4)

url_washt5 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=the-washington-times&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_washt5 = requests.get(url_washt5)

url_washt6 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=the-washington-times&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_washt6 = requests.get(url_washt6)

url_washt7 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=the-washington-times&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_washt7 = requests.get(url_washt7)

# %%
# Vice
url_vice1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_vice1 = requests.get(url_vice1)

url_vice2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_vice2 = requests.get(url_vice2)

url_vice3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_vice3 = requests.get(url_vice3)

url_vice4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_vice4 = requests.get(url_vice4)

url_vice5 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_vice5 = requests.get(url_vice5)

url_vice6 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_vice6 = requests.get(url_vice6)

url_vice7 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_vice7 = requests.get(url_vice7)

# %% [markdown]
# sadasas

# %%
# MSCBC
url_msnbc1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_msnbc1 = requests.get(url_msnbc1)

url_msnbc2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_msnbc2 = requests.get(url_msnbc2)

url_msnbc3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_msnbc3 = requests.get(url_msnbc3)

url_msnbc4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_msnbc4 = requests.get(url_msnbc4)

url_msnbc5 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_msnbc5 = requests.get(url_msnbc5)

url_msnbc46 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_msnbc6 = requests.get(url_msnbc46)

url_msnbc47 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_msnbc7= requests.get(url_msnbc47)

# %%
# Buzzfeed
url_buzz1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_buzz1 = requests.get(url_buzz1)

url_buzz2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_buzz2 = requests.get(url_buzz2)

url_buzz3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_buzz3 = requests.get(url_buzz3)

url_buzz4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_buzz4 = requests.get(url_buzz4)

url_buzz45 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_buzz5 = requests.get(url_buzz45)

url_buzz46 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_buzz6 = requests.get(url_buzz46)

url_buzz47 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_buzz7 = requests.get(url_buzz47)

# %%
# CNN
url_cnn1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=cnn&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_cnn1 = requests.get(url_cnn1)

url_cnn2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=cnn&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_cnn2 = requests.get(url_cnn2)

url_cnn3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=cnn&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_cnn3 = requests.get(url_cnn3)

url_cnn4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=cnn&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_cnn4 = requests.get(url_cnn4)

url_cnn45 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=cnn&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_cnn5 = requests.get(url_cnn45)

url_cnn46 = ('http://newsapi.org/v2/everything?'
       'q=ukraine&'
       'sources=cnn&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_cnn6 = requests.get(url_cnn46)

url_cnn47 = ('http://newsapi.org/v2/everything?'
       'q=russia&'
       'sources=cnn&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_cnn7 = requests.get(url_cnn47)

# %%
# Politico
url_pol1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=politico&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_pol1 = requests.get(url_pol1)

url_pol2 = ('http://newsapi.org/v2/everything?'
       'q=election&'
       'sources=politico&'
        'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_pol2 = requests.get(url_pol2)

url_pol3 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=politico&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_pol3 = requests.get(url_pol3)

url_pol4 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=politico&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_pol4 = requests.get(url_pol4)

url_pol45 = ('http://newsapi.org/v2/everything?'
       'q=war&'
       'sources=politico&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_pol5 = requests.get(url_pol45)

url_pol6 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=politico&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_pol6 = requests.get(url_pol6)

url_pol47 = ('http://newsapi.org/v2/everything?'
       'q=bail&'
       'sources=politico&'
        'pageSize=100&'
       'sortBy=relevancy&'
       'apiKey=4d4ea4bf4ffe4e998ebd1a22a9fdf9d3')
response_pol7 = requests.get(url_pol47)

# %%
for i in range(5,8):
  print(f'response_nreview{i}_d = response_nreview{i}.content.decode("utf-8")')
# Out:
# response_nreview5_d = response_nreview5.content.decode("utf-8")
# response_nreview6_d = response_nreview6.content.decode("utf-8")
# response_nreview7_d = response_nreview7.content.decode("utf-8")

# %%
# Decoding News API Objects
print('Conservative sources, 1 partisan right, 4 skew right')

response_fox1_d = response_fox1.content.decode("utf-8")
response_fox2_d = response_fox2.content.decode("utf-8")
response_fox3_d = response_fox3.content.decode("utf-8")
response_fox4_d = response_fox4.content.decode("utf-8")
response_fox5_d = response_fox5.content.decode("utf-8")
response_fox6_d = response_fox6.content.decode("utf-8")
response_fox7_d = response_fox7.content.decode("utf-8")

response_bart1_d = response_bart1.content.decode("utf-8")
response_bart2_d = response_bart2.content.decode("utf-8")
response_bart3_d = response_bart3.content.decode("utf-8")
response_bart4_d = response_bart4.content.decode("utf-8")
response_bart5_d = response_bart5.content.decode("utf-8")
response_bart6_d = response_bart6.content.decode("utf-8")
response_bart7_d = response_bart7.content.decode("utf-8")

response_nreview1_d = response_nreview1.content.decode("utf-8")
response_nreview2_d = response_nreview2.content.decode("utf-8")
response_nreview3_d = response_nreview3.content.decode("utf-8")
response_nreview4_d = response_nreview4.content.decode("utf-8")
response_nreview5_d = response_nreview5.content.decode("utf-8")
response_nreview6_d = response_nreview6.content.decode("utf-8")
response_nreview7_d = response_nreview7.content.decode("utf-8")

response_amcon1_d = response_amcon1.content.decode("utf-8")
response_amcon2_d = response_amcon2.content.decode("utf-8")
response_amcon3_d = response_amcon3.content.decode("utf-8")
response_amcon4_d = response_amcon4.content.decode("utf-8")
response_amcon5_d = response_amcon5.content.decode("utf-8")
response_amcon6_d = response_amcon6.content.decode("utf-8")
response_amcon7_d = response_amcon7.content.decode("utf-8")


response_washt1_d = response_washt1.content.decode("utf-8")
response_washt2_d = response_washt2.content.decode("utf-8")
response_washt3_d = response_washt3.content.decode("utf-8")
response_washt4_d = response_washt4.content.decode("utf-8")
response_washt5_d = response_washt5.content.decode("utf-8")
response_washt6_d = response_washt6.content.decode("utf-8")
response_washt7_d = response_washt7.content.decode("utf-8")

# print(response_washt4_d)

print('Liberal sources, 1 partisan left, 4 skew left')

response_vice1_d = response_vice1.content.decode("utf-8")
response_vice2_d = response_vice2.content.decode("utf-8")
response_vice3_d = response_vice3.content.decode("utf-8")
response_vice4_d = response_vice4.content.decode("utf-8")
response_vice5_d = response_vice5.content.decode("utf-8")
response_vice6_d = response_vice6.content.decode("utf-8")
response_vice7_d = response_vice7.content.decode("utf-8")


response_msnbc1_d = response_msnbc1.content.decode("utf-8")
response_msnbc2_d = response_msnbc2.content.decode("utf-8")
response_msnbc3_d = response_msnbc3.content.decode("utf-8")
response_msnbc4_d = response_msnbc4.content.decode("utf-8")
response_msnbc5_d = response_msnbc5.content.decode("utf-8")
response_msnbc6_d = response_msnbc6.content.decode("utf-8")
response_msnbc7_d = response_msnbc7.content.decode("utf-8")


response_buzz1_d = response_buzz1.content.decode("utf-8")
response_buzz2_d = response_buzz2.content.decode("utf-8")
response_buzz3_d = response_buzz3.content.decode("utf-8")
response_buzz4_d = response_buzz4.content.decode("utf-8")
response_buzz5_d = response_buzz5.content.decode("utf-8")
response_buzz6_d = response_buzz6.content.decode("utf-8")
response_buzz7_d = response_buzz7.content.decode("utf-8")


response_cnn1_d = response_cnn1.content.decode("utf-8")
response_cnn2_d = response_cnn2.content.decode("utf-8")
response_cnn3_d = response_cnn3.content.decode("utf-8")
response_cnn4_d = response_cnn4.content.decode("utf-8")
response_cnn5_d = response_cnn5.content.decode("utf-8")
response_cnn6_d = response_cnn6.content.decode("utf-8")
response_cnn7_d = response_cnn7.content.decode("utf-8")


response_pol1_d = response_pol1.content.decode("utf-8")
response_pol2_d = response_pol2.content.decode("utf-8")
response_pol3_d = response_pol3.content.decode("utf-8")
response_pol4_d = response_pol4.content.decode("utf-8")
response_pol5_d = response_pol5.content.decode("utf-8")
response_pol6_d = response_pol6.content.decode("utf-8")
response_pol7_d = response_pol7.content.decode("utf-8")

#print(response_pol4_d)
# Out:
# Conservative sources, 1 partisan right, 4 skew right
# Liberal sources, 1 partisan left, 4 skew left

# %%
for i in range(1,8):
  print(f"response_fox{i}_j = json.loads(response_fox{i}_d)")
  print(f"response_bart{i}_j = json.loads(response_bart{i}_d)")
  print(f"response_nreview{i}_j = json.loads(response_nreview{i}_d)")
  print(f"response_amcon{i}_j = json.loads(response_amcon{i}_d)")
  print(f"response_vice{i}_j = json.loads(response_vice{i}_d)")
  print(f"response_msnbc{i}_j = json.loads(response_msnbc{i}_d)")
  print(f"response_buzz{i}_j = json.loads(response_buzz{i}_d)")
  print(f"response_cnn{i}_j = json.loads(response_cnn{i}_d)")
  print(f"response_pol{i}_j = json.loads(response_pol{i}_d)")
  print(f"response_washt{i}_j = json.loads(response_washt{i}_d)")
# Out:
# response_fox1_j = json.loads(response_fox1_d)
# response_bart1_j = json.loads(response_bart1_d)
# response_nreview1_j = json.loads(response_nreview1_d)
# response_amcon1_j = json.loads(response_amcon1_d)
# response_vice1_j = json.loads(response_vice1_d)
# response_msnbc1_j = json.loads(response_msnbc1_d)
# response_buzz1_j = json.loads(response_buzz1_d)
# response_cnn1_j = json.loads(response_cnn1_d)
# response_pol1_j = json.loads(response_pol1_d)
# response_washt1_j = json.loads(response_washt1_d)
# response_fox2_j = json.loads(response_fox2_d)
# response_bart2_j = json.loads(response_bart2_d)
# response_nreview2_j = json.loads(response_nreview2_d)
# response_amcon2_j = json.loads(response_amcon2_d)
# response_vice2_j = json.loads(response_vice2_d)
# response_msnbc2_j = json.loads(response_msnbc2_d)
# response_buzz2_j = json.loads(response_buzz2_d)
# response_cnn2_j = json.loads(response_cnn2_d)
# response_pol2_j = json.loads(response_pol2_d)
# ...

# %%
import json
response_fox1_j = json.loads(response_fox1_d)
response_bart1_j = json.loads(response_bart1_d)
response_nreview1_j = json.loads(response_nreview1_d)
response_amcon1_j = json.loads(response_amcon1_d)
response_vice1_j = json.loads(response_vice1_d)
response_msnbc1_j = json.loads(response_msnbc1_d)
response_buzz1_j = json.loads(response_buzz1_d)
response_cnn1_j = json.loads(response_cnn1_d)
response_pol1_j = json.loads(response_pol1_d)
response_washt1_j = json.loads(response_washt1_d)
response_fox2_j = json.loads(response_fox2_d)
response_bart2_j = json.loads(response_bart2_d)
response_nreview2_j = json.loads(response_nreview2_d)
response_amcon2_j = json.loads(response_amcon2_d)
response_vice2_j = json.loads(response_vice2_d)
response_msnbc2_j = json.loads(response_msnbc2_d)
response_buzz2_j = json.loads(response_buzz2_d)
response_cnn2_j = json.loads(response_cnn2_d)
response_pol2_j = json.loads(response_pol2_d)
response_washt2_j = json.loads(response_washt2_d)
response_fox3_j = json.loads(response_fox3_d)
response_bart3_j = json.loads(response_bart3_d)
response_nreview3_j = json.loads(response_nreview3_d)
response_amcon3_j = json.loads(response_amcon3_d)
response_vice3_j = json.loads(response_vice3_d)
response_msnbc3_j = json.loads(response_msnbc3_d)
response_buzz3_j = json.loads(response_buzz3_d)
response_cnn3_j = json.loads(response_cnn3_d)
response_pol3_j = json.loads(response_pol3_d)
response_washt3_j = json.loads(response_washt3_d)
response_fox4_j = json.loads(response_fox4_d)
response_bart4_j = json.loads(response_bart4_d)
response_nreview4_j = json.loads(response_nreview4_d)
response_amcon4_j = json.loads(response_amcon4_d)
response_vice4_j = json.loads(response_vice4_d)
response_msnbc4_j = json.loads(response_msnbc4_d)
response_buzz4_j = json.loads(response_buzz4_d)
response_cnn4_j = json.loads(response_cnn4_d)
response_pol4_j = json.loads(response_pol4_d)
response_washt4_j = json.loads(response_washt4_d)
response_fox5_j = json.loads(response_fox5_d)
response_bart5_j = json.loads(response_bart5_d)
response_nreview5_j = json.loads(response_nreview5_d)
response_amcon5_j = json.loads(response_amcon5_d)
response_vice5_j = json.loads(response_vice5_d)
response_msnbc5_j = json.loads(response_msnbc5_d)
response_buzz5_j = json.loads(response_buzz5_d)
response_cnn5_j = json.loads(response_cnn5_d)
response_pol5_j = json.loads(response_pol5_d)
response_washt5_j = json.loads(response_washt5_d)
response_fox6_j = json.loads(response_fox6_d)
response_bart6_j = json.loads(response_bart6_d)
response_nreview6_j = json.loads(response_nreview6_d)
response_amcon6_j = json.loads(response_amcon6_d)
response_vice6_j = json.loads(response_vice6_d)
response_msnbc6_j = json.loads(response_msnbc6_d)
response_buzz6_j = json.loads(response_buzz6_d)
response_cnn6_j = json.loads(response_cnn6_d)
response_pol6_j = json.loads(response_pol6_d)
response_washt6_j = json.loads(response_washt6_d)
response_fox7_j = json.loads(response_fox7_d)
response_bart7_j = json.loads(response_bart7_d)
response_nreview7_j = json.loads(response_nreview7_d)
response_amcon7_j = json.loads(response_amcon7_d)
response_vice7_j = json.loads(response_vice7_d)
response_msnbc7_j = json.loads(response_msnbc7_d)
response_buzz7_j = json.loads(response_buzz7_d)
response_cnn7_j = json.loads(response_cnn7_d)
response_pol7_j = json.loads(response_pol7_d)
response_washt7_j = json.loads(response_washt7_d)

# %%
response_fox1_j
# Out:
# {'articles': [{'author': 'Kate Pearce',
#    'content': 'The first election of 2022 is\xa0less than a month away\xa0as Texas gears up for its Primary on March 1st. Professor at the University of Texas in Austin &amp; member of the FOX News Decision Desk\xa0Daron Sh… [+376 chars]',
#    'description': 'The first election of 2022 is\xa0less than a month away\xa0as Texas gears up for its Primary on March 1st. Professor at the University of Texas in Austin & member of the FOX News Decision Desk\xa0Daron Shaw shares if the results from this election can act as a bellwet…',
#    'publishedAt': '2022-02-06T10:00:02Z',
#    'source': {'id': 'fox-news', 'name': 'Fox News'},
#    'title': 'From Washington: It All Starts In Texas',
#    'url': 'https://radio.foxnews.com/2022/02/06/from-washington-it-all-starts-in-texas/',
#    'urlToImage': 'https://radio.foxnews.com/wp-content/uploads/2022/01/FOX_NEWS_RUNDOWN_FROM_WASHINGTON_COVER_2G-1.png'},
#   {'author': 'Christine DeSanctis',
# ...

# %%
for i in range(1,8):
  print(f"df_fox{i} = pd.DataFrame(response_fox{i}_j['articles']) ")
  print( f"df_bart{i} = pd.DataFrame(response_bart{i}_j['articles'])") 
  print(f"df_nreview{i} = pd.DataFrame(response_nreview{i}_j['articles'])")
  print(f"df_amcon{i} = pd.DataFrame(response_amcon{i}_j['articles'])")
  print(f"df_washt{i} = pd.DataFrame(response_washt{i}_j['articles'])")
  print(f"df_vice{i} = pd.DataFrame(response_vice{i}_j['articles'])")
  print(f"df_vice{i} = pd.DataFrame(response_vice{i}_j['articles'])")
  print(f"df_msnbc{i} = pd.DataFrame(response_msnbc{i}_j['articles'])")
  print(f"df_buzz{i} = pd.DataFrame(response_buzz{i}_j['articles'])")
  print(f"df_cnn{i} = pd.DataFrame(response_cnn{i}_j['articles'])")
  print(f"df_pol{i} = pd.DataFrame(response_pol{i}_j['articles'])")
# Out:
# df_fox1 = pd.DataFrame(response_fox1_j['articles'])
# df_bart1 = pd.DataFrame(response_bart1_j['articles'])
# df_nreview1 = pd.DataFrame(response_nreview1_j['articles'])
# df_amcon1 = pd.DataFrame(response_amcon1_j['articles'])
# df_washt1 = pd.DataFrame(response_washt1_j['articles'])
# df_vice1 = pd.DataFrame(response_vice1_j['articles'])
# df_vice1 = pd.DataFrame(response_vice1_j['articles'])
# df_msnbc1 = pd.DataFrame(response_msnbc1_j['articles'])
# df_buzz1 = pd.DataFrame(response_buzz1_j['articles'])
# df_cnn1 = pd.DataFrame(response_cnn1_j['articles'])
# df_pol1 = pd.DataFrame(response_pol1_j['articles'])
# df_fox2 = pd.DataFrame(response_fox2_j['articles'])
# df_bart2 = pd.DataFrame(response_bart2_j['articles'])
# df_nreview2 = pd.DataFrame(response_nreview2_j['articles'])
# df_amcon2 = pd.DataFrame(response_amcon2_j['articles'])
# df_washt2 = pd.DataFrame(response_washt2_j['articles'])
# df_vice2 = pd.DataFrame(response_vice2_j['articles'])
# ...

# %%
df_fox1 = pd.DataFrame(response_fox1_j['articles']) 
df_bart1 = pd.DataFrame(response_bart1_j['articles'])
df_nreview1 = pd.DataFrame(response_nreview1_j['articles'])
df_amcon1 = pd.DataFrame(response_amcon1_j['articles'])
df_washt1 = pd.DataFrame(response_washt1_j['articles'])
df_vice1 = pd.DataFrame(response_vice1_j['articles'])
df_vice1 = pd.DataFrame(response_vice1_j['articles'])
df_msnbc1 = pd.DataFrame(response_msnbc1_j['articles'])
df_buzz1 = pd.DataFrame(response_buzz1_j['articles'])
df_cnn1 = pd.DataFrame(response_cnn1_j['articles'])
df_pol1 = pd.DataFrame(response_pol1_j['articles'])
df_fox2 = pd.DataFrame(response_fox2_j['articles']) 
df_bart2 = pd.DataFrame(response_bart2_j['articles'])
df_nreview2 = pd.DataFrame(response_nreview2_j['articles'])
df_amcon2 = pd.DataFrame(response_amcon2_j['articles'])
df_washt2 = pd.DataFrame(response_washt2_j['articles'])
df_vice2 = pd.DataFrame(response_vice2_j['articles'])
df_vice2 = pd.DataFrame(response_vice2_j['articles'])
df_msnbc2 = pd.DataFrame(response_msnbc2_j['articles'])
df_buzz2 = pd.DataFrame(response_buzz2_j['articles'])
df_cnn2 = pd.DataFrame(response_cnn2_j['articles'])
df_pol2 = pd.DataFrame(response_pol2_j['articles'])
df_fox3 = pd.DataFrame(response_fox3_j['articles']) 
df_bart3 = pd.DataFrame(response_bart3_j['articles'])
df_nreview3 = pd.DataFrame(response_nreview3_j['articles'])
df_amcon3 = pd.DataFrame(response_amcon3_j['articles'])
df_washt3 = pd.DataFrame(response_washt3_j['articles'])
df_vice3 = pd.DataFrame(response_vice3_j['articles'])
df_vice3 = pd.DataFrame(response_vice3_j['articles'])
df_msnbc3 = pd.DataFrame(response_msnbc3_j['articles'])
df_buzz3 = pd.DataFrame(response_buzz3_j['articles'])
df_cnn3 = pd.DataFrame(response_cnn3_j['articles'])
df_pol3 = pd.DataFrame(response_pol3_j['articles'])
df_fox4 = pd.DataFrame(response_fox4_j['articles']) 
df_bart4 = pd.DataFrame(response_bart4_j['articles'])
df_nreview4 = pd.DataFrame(response_nreview4_j['articles'])
df_amcon4 = pd.DataFrame(response_amcon4_j['articles'])
df_washt4 = pd.DataFrame(response_washt4_j['articles'])
df_vice4 = pd.DataFrame(response_vice4_j['articles'])
df_vice4 = pd.DataFrame(response_vice4_j['articles'])
df_msnbc4 = pd.DataFrame(response_msnbc4_j['articles'])
df_buzz4 = pd.DataFrame(response_buzz4_j['articles'])
df_cnn4 = pd.DataFrame(response_cnn4_j['articles'])
df_pol4 = pd.DataFrame(response_pol4_j['articles'])
df_fox5 = pd.DataFrame(response_fox5_j['articles']) 
df_bart5 = pd.DataFrame(response_bart5_j['articles'])
df_nreview5 = pd.DataFrame(response_nreview5_j['articles'])
df_amcon5 = pd.DataFrame(response_amcon5_j['articles'])
df_washt5 = pd.DataFrame(response_washt5_j['articles'])
df_vice5 = pd.DataFrame(response_vice5_j['articles'])
df_vice5 = pd.DataFrame(response_vice5_j['articles'])
df_msnbc5 = pd.DataFrame(response_msnbc5_j['articles'])
df_buzz5 = pd.DataFrame(response_buzz5_j['articles'])
df_cnn5 = pd.DataFrame(response_cnn5_j['articles'])
df_pol5 = pd.DataFrame(response_pol5_j['articles'])
df_fox6 = pd.DataFrame(response_fox6_j['articles']) 
df_bart6 = pd.DataFrame(response_bart6_j['articles'])
df_nreview6 = pd.DataFrame(response_nreview6_j['articles'])
df_amcon6 = pd.DataFrame(response_amcon6_j['articles'])
df_washt6 = pd.DataFrame(response_washt6_j['articles'])
df_vice6 = pd.DataFrame(response_vice6_j['articles'])
df_vice6 = pd.DataFrame(response_vice6_j['articles'])
df_msnbc6 = pd.DataFrame(response_msnbc6_j['articles'])
df_buzz6 = pd.DataFrame(response_buzz6_j['articles'])
df_cnn6 = pd.DataFrame(response_cnn6_j['articles'])
df_pol6 = pd.DataFrame(response_pol6_j['articles'])
df_fox7 = pd.DataFrame(response_fox7_j['articles']) 
df_bart7 = pd.DataFrame(response_bart7_j['articles'])
df_nreview7 = pd.DataFrame(response_nreview7_j['articles'])
df_amcon7 = pd.DataFrame(response_amcon7_j['articles'])
df_washt7 = pd.DataFrame(response_washt7_j['articles'])
df_vice7 = pd.DataFrame(response_vice7_j['articles'])
df_vice7 = pd.DataFrame(response_vice7_j['articles'])
df_msnbc7 = pd.DataFrame(response_msnbc7_j['articles'])
df_buzz7 = pd.DataFrame(response_buzz7_j['articles'])
df_cnn7 = pd.DataFrame(response_cnn7_j['articles'])
df_pol7 = pd.DataFrame(response_pol7_j['articles'])

# %%
for i in range(1,8):
  print(f'df_fox{i},df_bart{i}, df_nreview{i},df_amcon{i},df_washt{i},df_msnbc{i},df_buzz{i},df_vice{i},df_cnn{i}, df_pol{i},')
# Out:
# df_fox1,df_bart1, df_nreview1,df_amcon1,df_washt1,df_msnbc1,df_buzz1,df_vice1,df_cnn1, df_pol1,
# df_fox2,df_bart2, df_nreview2,df_amcon2,df_washt2,df_msnbc2,df_buzz2,df_vice2,df_cnn2, df_pol2,
# df_fox3,df_bart3, df_nreview3,df_amcon3,df_washt3,df_msnbc3,df_buzz3,df_vice3,df_cnn3, df_pol3,
# df_fox4,df_bart4, df_nreview4,df_amcon4,df_washt4,df_msnbc4,df_buzz4,df_vice4,df_cnn4, df_pol4,
# df_fox5,df_bart5, df_nreview5,df_amcon5,df_washt5,df_msnbc5,df_buzz5,df_vice5,df_cnn5, df_pol5,
# df_fox6,df_bart6, df_nreview6,df_amcon6,df_washt6,df_msnbc6,df_buzz6,df_vice6,df_cnn6, df_pol6,
# df_fox7,df_bart7, df_nreview7,df_amcon7,df_washt7,df_msnbc7,df_buzz7,df_vice7,df_cnn7, df_pol7,

# %%
# Concat all sources together
df_allsources = pd.concat([
df_fox1,df_bart1, df_nreview1,df_amcon1,df_washt1,df_msnbc1,df_buzz1,df_vice1,df_cnn1, df_pol1,
df_fox2,df_bart2, df_nreview2,df_amcon2,df_washt2,df_msnbc2,df_buzz2,df_vice2,df_cnn2, df_pol2,
df_fox3,df_bart3, df_nreview3,df_amcon3,df_washt3,df_msnbc3,df_buzz3,df_vice3,df_cnn3, df_pol3,
df_fox4,df_bart4, df_nreview4,df_amcon4,df_washt4,df_msnbc4,df_buzz4,df_vice4,df_cnn4, df_pol4,
df_fox5,df_bart5, df_nreview5,df_amcon5,df_washt5,df_msnbc5,df_buzz5,df_vice5,df_cnn5, df_pol5,
df_fox6,df_bart6, df_nreview6,df_amcon6,df_washt6,df_msnbc6,df_buzz6,df_vice6,df_cnn6, df_pol6,
df_fox7,df_bart7, df_nreview7,df_amcon7,df_washt7,df_msnbc7,df_buzz7,df_vice7,df_cnn7, df_pol7])
df_allsources
# Out:
#                                     source  \
# 0   {'id': 'fox-news', 'name': 'Fox News'}
# 1   {'id': 'fox-news', 'name': 'Fox News'}
# 2   {'id': 'fox-news', 'name': 'Fox News'}
# 3   {'id': 'fox-news', 'name': 'Fox News'}
# 4   {'id': 'fox-news', 'name': 'Fox News'}
# ..                                     ...
# 17  {'id': 'politico', 'name': 'Politico'}
# 18  {'id': 'politico', 'name': 'Politico'}
# 19  {'id': 'politico', 'name': 'Politico'}
# 20  {'id': 'politico', 'name': 'Politico'}
# 21  {'id': 'politico', 'name': 'Politico'}
#
#                                               author  \
# 0                                        Kate Pearce
# 1                                Christine DeSanctis
# 2                                Wyatt DobrovichFago
# 3                                Wyatt DobrovichFago
# 4                                    William Sanchez
# ..                                               ...
# 17  By Erin Durkin, Anna Gronewold and Deanna Garcia
# ...

# %%
# Write to csv file
filename='newsapi_scrape3_03-04.csv'
df_allsources.to_csv(filename, index=False)

# %%
from google.colab import files
files.download(filename)
